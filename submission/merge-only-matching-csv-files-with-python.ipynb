# %% [markdown]
# # Import Libraries

# %%
import os
import glob
import pandas as pd

# %% [markdown]
# # Find all the file names to merge

# %%
data_folder = './data'
data_folder = './archive/stock_market_data/nasdaq/csv'

os.chdir(data_folder)

# %%
stocks_in_graph_data = ['AAL',
  'AAPL',
  'ALGN',
  'AMD',
  'AMGN',
  'AMZN',
  'ATVI',
  'BIDU',
  'BIIB',
  'CAC',
  'CAR',
  #'CBOE',
  'CCRN',
  'CDNS',
  'CHKP',
  'CMCSA',
  'COST',
  'CYH',
  'EBAY',
  'EQIX',
  'EXAS',
  'FFIV',
  #'FREE',
  'FUND',
  #'III',
  'INTC',
  'IRBT',
  'ISRG',
  'LRCX',
  'MITK',
  'MKSI',
  'MPAA',
  'MSFT',
  'NFLX',
  'NVDA',
  'NWBI',
  'OIS',
  'OKE',
  'PNFP',
  'REGN',
  'ROST',
  'RRGB',
  #'RVNC',
  'SBUX',
  'SEAC',
  'SGEN',
  'SIMO',
  'SWKS',
  'TXN',
  'VRTX',
  'WDC']

# %%
# Not Used fileTypesToMerge; may use for daily close price or price in every minute data

fileTypesToMerge = '';
extension = 'csv';
all_filenames = [i for i in glob.glob('*' + fileTypesToMerge + '*.{}'.format(extension))]
all_filenames_no_extension = [i[:-4] for i in glob.glob('*' + fileTypesToMerge + '*.{}'.format(extension))]
all_filenames[:10]

# take a subset of the data for experiment
list_of_files_to_process = list(set(all_filenames_no_extension).intersection(set(stocks_in_graph_data))) #[:10]
list_of_files_to_process[:100]
# Out:
# ['FFIV',
#  'BIDU',
#  'ROST',
#  'CDNS',
#  'CCRN',
#  'NWBI',
#  'IRBT',
#  'SGEN',
#  'AMD',
#  'ISRG',
#  'REGN',
#  'NVDA',
#  'AMGN',
#  'ALGN',
#  'TXN',
#  'AAL',
#  'SBUX',
#  'AMZN',
#  'OIS',
#  'SEAC',
#  'LRCX',
#  'CYH',
#  'BIIB',
#  'SWKS',
#  'CHKP',
#  'CAR',
#  'MKSI',
#  'EQIX',
#  'WDC',
#  'MITK',
#  'RRGB',
#  'CAC',
#  'NFLX',
#  'OKE',
#  'SIMO',
#  'MPAA',
#  'COST',
#  'VRTX',
#  'EBAY',
#  'CMCSA',
#  'PNFP',
#  'AAPL',
#  'INTC',
#  'ATVI',
#  'EXAS',
#  'FUND',
#  'MSFT']

# %%
len(list_of_files_to_process)
# Out:
# 47

# %% [markdown]
# # Insert Stock Ticker. Save data in new files

# %%
from os.path import exists
row_total_count = 0
# modified = 'modified/'
modified = 'modified/'
for f in list_of_files_to_process:
    f = f + ".csv";
    print(f);
    
    file_exists = exists(modified + f)
    if file_exists:
        # print('file exists');
        # break;
        continue;

    try:    
        df_s = pd.read_csv(f)
        df_s.insert(0, "Ticker", [f[:-4]] * df_s.shape[0], allow_duplicates = True)
        
        print(min(df_s['Date']))
        
        df_s.to_csv(modified + f);
        row_total_count += df_s.shape[0]
    except:
        continue;
    finally:
        continue;

row_total_count
# Out:
# FFIV.csv
# BIDU.csv
# ROST.csv
# CDNS.csv
# CCRN.csv
# NWBI.csv
# IRBT.csv
# SGEN.csv
# AMD.csv
# ISRG.csv
# REGN.csv
# NVDA.csv
# AMGN.csv
# ALGN.csv
# TXN.csv
# AAL.csv
# SBUX.csv
# AMZN.csv
# OIS.csv
# SEAC.csv
# LRCX.csv
# CYH.csv
# BIIB.csv
# SWKS.csv
# CHKP.csv
# CAR.csv
# MKSI.csv
# EQIX.csv
# WDC.csv
# MITK.csv
# RRGB.csv
# CAC.csv
# NFLX.csv
# OKE.csv
# SIMO.csv
# MPAA.csv
# COST.csv
# VRTX.csv
# EBAY.csv
# CMCSA.csv
# PNFP.csv
# AAPL.csv
# INTC.csv
# ATVI.csv
# EXAS.csv
# FUND.csv
# MSFT.csv
# 0

# %% [markdown]
# # Combine all files in the list into one file

# %%
# Combine

combined_csv = pd.concat([pd.read_csv(modified + f + ".csv") for f in list_of_files_to_process]);

# export to csv
#combined_csv.to_csv( "../combined_data/stock-price-" + fileTypesToMerge + "-all-merged.csv", index = False, encoding = 'utf-8-sig')
combined_csv.to_csv( "../nasdq-stock-price-" + fileTypesToMerge + "-all-merged.csv", index = False, encoding = 'utf-8-sig')

# %% [markdown]
# # Compare the size before and after merging

# %%
print('Size before Merge');
row_total_count
# Out:
# Size before Merge
# 0

# %%
print('Size After Merge');
#df = pd.read_csv("../combined_data/stock-price-" + fileTypesToMerge + "-all-merged.csv")
df = pd.read_csv("../nasdq-stock-price-" + fileTypesToMerge + "-all-merged.csv")
df.shape
# Out:
# Size After Merge
# C:\Users\sayed\AppData\Local\Temp\ipykernel_19912\3250555256.py:3: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../nasdq-stock-price-" + fileTypesToMerge + "-all-merged.csv")
# (351369, 13)

# %%
# Check the combined data

# %%
df.head()
# df.tail()
# Out:
#    Unnamed: 0 Ticker        Date     Low     Open     Volume      High  \
# 0           0   FFIV  04-06-1999  5.0625    5.125  7386600.0  7.921875
# 1           1   FFIV  07-06-1999  7.3125  7.90625  1234600.0    8.3125
# 2           2   FFIV  08-06-1999  7.7500   7.8125  1477200.0   10.1875
# 3           3   FFIV  09-06-1999  9.3125     10.0  1332600.0  10.59375
# 4           4   FFIV  10-06-1999  8.5000   9.6875   545600.0   9.84375
#
#      Close  Adjusted Close  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10
# 0  7.43750         7.43750         NaN         NaN         NaN          NaN
# 1  7.75000         7.75000         NaN         NaN         NaN          NaN
# 2  9.84375         9.84375         NaN         NaN         NaN          NaN
# 3  9.68750         9.68750         NaN         NaN         NaN          NaN
# 4  8.59375         8.59375         NaN         NaN         NaN          NaN

# %%
df.T
# Out:
#                     0           1           2           3           4       \
# Unnamed: 0               0           1           2           3           4
# Ticker                FFIV        FFIV        FFIV        FFIV        FFIV
# Date            04-06-1999  07-06-1999  08-06-1999  09-06-1999  10-06-1999
# Low                 5.0625      7.3125        7.75      9.3125         8.5
# Open                 5.125     7.90625      7.8125        10.0      9.6875
# Volume           7386600.0   1234600.0   1477200.0   1332600.0    545600.0
# High              7.921875      8.3125     10.1875    10.59375     9.84375
# Close               7.4375        7.75     9.84375      9.6875     8.59375
# Adjusted Close      7.4375        7.75     9.84375      9.6875     8.59375
# Unnamed: 7             NaN         NaN         NaN         NaN         NaN
# Unnamed: 8             NaN         NaN         NaN         NaN         NaN
# Unnamed: 9             NaN         NaN         NaN         NaN         NaN
# Unnamed: 10            NaN         NaN         NaN         NaN         NaN
#
#                     5           6           7           8           9       \
# Unnamed: 0               5           6           7           8           9
# Ticker                FFIV        FFIV        FFIV        FFIV        FFIV
# Date            11-06-1999  14-06-1999  15-06-1999  16-06-1999  17-06-1999
# Low                 7.9375        7.25      7.4375      7.8125       8.375
# Open                 8.625     7.96875      7.4375       7.875      8.4375
# Volume            446200.0    503600.0    384400.0    135400.0    814000.0
# High                8.6875         8.0      8.0625      8.9375    10.40625
# Close                  8.0       7.625        7.75     8.34375    10.03125
# Adjusted Close         8.0       7.625        7.75     8.34375    10.03125
# Unnamed: 7             NaN         NaN         NaN         NaN         NaN
# Unnamed: 8             NaN         NaN         NaN         NaN         NaN
# Unnamed: 9             NaN         NaN         NaN         NaN         NaN
# Unnamed: 10            NaN         NaN         NaN         NaN         NaN
#
#                 ...      351359      351360      351361      351362  \
# Unnamed: 0      ...        9254        9255        9256        9257
# Ticker          ...        MSFT        MSFT        MSFT        MSFT
# Date            ...  29-11-2022  30-11-2022  01-12-2022  02-12-2022
# Low             ...  238.210007  239.860001  250.919998  249.690002
# Open            ...  241.399994  240.570007  253.869995  249.820007
# Volume          ...  17956300.0  47553800.0  26041500.0  21522800.0
# High            ...  242.789993  255.330002  256.119995  256.059998
# Close           ...  240.330002  255.139999  254.690002  255.020004
# Adjusted Close  ...  240.330002  255.139999  254.690002  255.020004
# Unnamed: 7      ...         NaN         NaN         NaN         NaN
# Unnamed: 8      ...         NaN         NaN         NaN         NaN
# Unnamed: 9      ...         NaN         NaN         NaN         NaN
# Unnamed: 10     ...         NaN         NaN         NaN         NaN
#
#                     351363      351364      351365      351366      351367  \
# Unnamed: 0            9258        9259        9260        9261        9262
# Ticker                MSFT        MSFT        MSFT        MSFT        MSFT
# Date            05-12-2022  06-12-2022  07-12-2022  08-12-2022  09-12-2022
# Low             248.059998  243.779999  242.210007  243.059998  244.160004
# Open            252.009995  250.820007  244.830002  244.839996  244.699997
# Volume          23435300.0  22463700.0  20481500.0  22611800.0  20607100.0
# High            253.820007  251.860001  246.160004  248.740005  248.309998
# Close           250.199997  245.119995  244.369995  247.399994  245.419998
# Adjusted Close  250.199997  245.119995  244.369995  247.399994  245.419998
# Unnamed: 7             NaN         NaN         NaN         NaN         NaN
# Unnamed: 8             NaN         NaN         NaN         NaN         NaN
# Unnamed: 9             NaN         NaN         NaN         NaN         NaN
# Unnamed: 10            NaN         NaN         NaN         NaN         NaN
#
#                     351368
# Unnamed: 0            9263
# Ticker                MSFT
# Date            12-12-2022
# Low             247.179993
# Open            247.445007
# Volume          10714493.0
# High            252.151596
# Close           250.669998
# Adjusted Close  250.669998
# Unnamed: 7             NaN
# Unnamed: 8             NaN
# Unnamed: 9             NaN
# Unnamed: 10            NaN
#
# [13 rows x 351369 columns]

# %%
# find dates of the stock prices
import datetime

min_date_to_work_with = datetime.date(1900,1,1);

for f in list_of_files_to_process:
    f = f + ".csv";
    
    file_exists = exists(modified + f)
    if file_exists:

        df_s = pd.read_csv(modified + f, parse_dates=['Date'], dayfirst=True)          
        #pd.to_datetime(df_s.day, dayfirst=True)
        #df_s["Date"] = df_s["Date"].astype('datetime64[ns]');
        
        min_ticker = min(df_s['Date'])
        #min_date = s.split("-");
        #min_ticker = datetime.date(int(min_date[2]), int(min_date[1]), int(min_date[0]));
        #print(min_ticker, min_date_to_work_with)
        if (pd.Timestamp(min_ticker) > pd.Timestamp(min_date_to_work_with)):
            min_date_to_work_with = min_ticker
            print(f, min_date_to_work_with);
# Out:
# FFIV.csv 1999-06-04 00:00:00
# BIDU.csv 2005-08-05 00:00:00
# IRBT.csv 2005-11-09 00:00:00

# %%
# find dates of the stock prices
import datetime

max_date_to_work_with = datetime.date(2025,1,1);

for f in list_of_files_to_process:
    f = f + ".csv";
    
    file_exists = exists(modified + f)
    if file_exists:

        df_s = pd.read_csv(modified + f, parse_dates=['Date'], dayfirst=True)          
        
        max_ticker = max(df_s['Date'])
        print(f, max_date_to_work_with);
        if (pd.Timestamp(max_ticker) < pd.Timestamp(max_date_to_work_with)):
            max_date_to_work_with = max_ticker
            print(f, max_date_to_work_with);
# Out:
# FFIV.csv 2025-01-01
# FFIV.csv 2022-12-12 00:00:00
# BIDU.csv 2022-12-12 00:00:00
# ROST.csv 2022-12-12 00:00:00
# CDNS.csv 2022-12-12 00:00:00
# CCRN.csv 2022-12-12 00:00:00
# NWBI.csv 2022-12-12 00:00:00
# IRBT.csv 2022-12-12 00:00:00
# SGEN.csv 2022-12-12 00:00:00
# AMD.csv 2022-12-12 00:00:00
# ISRG.csv 2022-12-12 00:00:00
# REGN.csv 2022-12-12 00:00:00
# NVDA.csv 2022-12-12 00:00:00
# AMGN.csv 2022-12-12 00:00:00
# ALGN.csv 2022-12-12 00:00:00
# TXN.csv 2022-12-12 00:00:00
# AAL.csv 2022-12-12 00:00:00
# SBUX.csv 2022-12-12 00:00:00
# AMZN.csv 2022-12-12 00:00:00
# OIS.csv 2022-12-12 00:00:00
# SEAC.csv 2022-12-12 00:00:00
# LRCX.csv 2022-12-12 00:00:00
# CYH.csv 2022-12-12 00:00:00
# BIIB.csv 2022-12-12 00:00:00
# SWKS.csv 2022-12-12 00:00:00
# CHKP.csv 2022-12-12 00:00:00
# CAR.csv 2022-12-12 00:00:00
# MKSI.csv 2022-12-12 00:00:00
# EQIX.csv 2022-12-12 00:00:00
# WDC.csv 2022-12-12 00:00:00
# MITK.csv 2022-12-12 00:00:00
# RRGB.csv 2022-12-12 00:00:00
# CAC.csv 2022-12-12 00:00:00
# NFLX.csv 2022-12-12 00:00:00
# OKE.csv 2022-12-12 00:00:00
# SIMO.csv 2022-12-12 00:00:00
# MPAA.csv 2022-12-12 00:00:00
# COST.csv 2022-12-12 00:00:00
# VRTX.csv 2022-12-12 00:00:00
# EBAY.csv 2022-12-12 00:00:00
# CMCSA.csv 2022-12-12 00:00:00
# PNFP.csv 2022-12-12 00:00:00
# AAPL.csv 2022-12-12 00:00:00
# INTC.csv 2022-12-12 00:00:00
# ATVI.csv 2022-12-12 00:00:00
# EXAS.csv 2022-12-12 00:00:00
# FUND.csv 2022-12-12 00:00:00
# MSFT.csv 2022-12-12 00:00:00

# %%
df["Date"] = df["Date"].astype('datetime64[ns]')
df = df.sort_values( by = 'Date', ascending = True )
df
# Out:
# C:\Users\sayed\AppData\Local\Temp\ipykernel_19912\2147374738.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = df["Date"].astype('datetime64[ns]')
#         Unnamed: 0 Ticker       Date         Low        Open      Volume  \
# 96721            0    TXN 1972-01-06    1.690104         0.0    825600.0
# 96763           42    TXN 1972-01-08    1.785156     1.78776   1843200.0
# 96786           65    TXN 1972-01-09    1.825521    1.825521    499200.0
# 96828          107    TXN 1972-01-11    1.833333     1.85026   1248000.0
# 96848          127    TXN 1972-01-12    1.781250     1.78125   1420800.0
# ...            ...    ...        ...         ...         ...         ...
# 282809        6094   EBAY 2022-12-12   43.105000   43.700001   1069893.0
# 96720         5502   ALGN 2022-12-12  188.399994  190.949997    302227.0
# 247996       10639    OKE 2022-12-12   63.810001   63.919998    531690.0
# 351368        9263   MSFT 2022-12-12  247.179993  247.445007  10714493.0
# 149705        9731   LRCX 2022-12-13  457.519989         455       455.0
#
#               High       Close  Adjusted Close  Unnamed: 7  Unnamed: 8  \
# 96721     1.704427    1.701823        0.739382         NaN         NaN
# 96763     1.820313    1.820313        0.791849         NaN         NaN
# 96786     1.847656    1.830729        0.796379         NaN         NaN
# 96828     1.856771    1.843750        0.803002         NaN         NaN
# 96848     1.795573    1.795573        0.782020         NaN         NaN
# ...            ...         ...             ...         ...         ...
# 282809       43.57   43.330002       43.330002         NaN         NaN
# 96720   195.850006  195.410004      195.410004         NaN         NaN
# 247996   64.894997   64.739998       64.739998         NaN         NaN
# 351368  252.151596  250.669998      250.669998         NaN         NaN
# 149705         NaN         NaN             NaN         NaN         NaN
#
#         Unnamed: 9  Unnamed: 10
# 96721          NaN          NaN
# 96763          NaN          NaN
# 96786          NaN          NaN
# 96828          NaN          NaN
# 96848          NaN          NaN
# ...            ...          ...
# 282809         NaN          NaN
# 96720          NaN          NaN
# 247996         NaN          NaN
# 351368         NaN          NaN
# 149705         NaN          NaN
#
# [351369 rows x 13 columns]

# %%
df = df[ df['Date'] >= min_date_to_work_with ] 
df
# Out:
#         Unnamed: 0 Ticker       Date         Low               Open  \
# 227858        2014    CAC 2005-11-10   21.873333          22.686666
# 29650          997   CCRN 2005-11-10   16.719999          17.469999
# 185118        5571    CAR 2005-11-10   31.216000  31.95199966430664
# 337782        4375   FUND 2005-11-10    9.600000               9.62
# 175224        2337   CHKP 2005-11-10   21.110001  21.64999961853028
# ...            ...    ...        ...         ...                ...
# 282809        6094   EBAY 2022-12-12   43.105000          43.700001
# 96720         5502   ALGN 2022-12-12  188.399994         190.949997
# 247996       10639    OKE 2022-12-12   63.810001          63.919998
# 351368        9263   MSFT 2022-12-12  247.179993         247.445007
# 149705        9731   LRCX 2022-12-13  457.519989                455
#
#             Volume                High       Close  Adjusted Close  \
# 227858     26700.0           22.686666   22.219999       13.136522
# 29650     152300.0               17.51   16.719999       16.719999
# 185118   2903000.0   32.20800018310547   31.375999       30.960777
# 337782     18500.0                9.72    9.600000        2.614000
# 175224   2843300.0  21.739999771118164   21.250000       21.250000
# ...            ...                 ...         ...             ...
# 282809   1069893.0               43.57   43.330002       43.330002
# 96720     302227.0          195.850006  195.410004      195.410004
# 247996    531690.0           64.894997   64.739998       64.739998
# 351368  10714493.0          252.151596  250.669998      250.669998
# 149705       455.0                 NaN         NaN             NaN
#
#         Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10
# 227858         NaN         NaN         NaN          NaN
# 29650          NaN         NaN         NaN          NaN
# 185118         NaN         NaN         NaN          NaN
# 337782         NaN         NaN         NaN          NaN
# 175224         NaN         NaN         NaN          NaN
# ...            ...         ...         ...          ...
# 282809         NaN         NaN         NaN          NaN
# 96720          NaN         NaN         NaN          NaN
# 247996         NaN         NaN         NaN          NaN
# 351368         NaN         NaN         NaN          NaN
# 149705         NaN         NaN         NaN          NaN
#
# [202128 rows x 13 columns]

# %%
df = df[ df['Date'] <= max_date_to_work_with ] 
df.head()
df.tail()
# Out:
#         Unnamed: 0 Ticker       Date         Low        Open      Volume  \
# 33972         5319   CCRN 2022-12-12   27.820000   30.200001    508443.0
# 282809        6094   EBAY 2022-12-12   43.105000   43.700001   1069893.0
# 96720         5502   ALGN 2022-12-12  188.399994  190.949997    302227.0
# 247996       10639    OKE 2022-12-12   63.810001   63.919998    531690.0
# 351368        9263   MSFT 2022-12-12  247.179993  247.445007  10714493.0
#
#               High       Close  Adjusted Close  Unnamed: 7  Unnamed: 8  \
# 33972       30.395   29.395000       29.395000         NaN         NaN
# 282809       43.57   43.330002       43.330002         NaN         NaN
# 96720   195.850006  195.410004      195.410004         NaN         NaN
# 247996   64.894997   64.739998       64.739998         NaN         NaN
# 351368  252.151596  250.669998      250.669998         NaN         NaN
#
#         Unnamed: 9  Unnamed: 10
# 33972          NaN          NaN
# 282809         NaN          NaN
# 96720          NaN          NaN
# 247996         NaN          NaN
# 351368         NaN          NaN

# %%
df.to_csv( "../nasdq-stock-price-" + fileTypesToMerge + "-all-merged.csv", index = False, encoding = 'utf-8-sig')
